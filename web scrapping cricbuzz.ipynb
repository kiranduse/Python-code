# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url='https://www.cricbuzz.com/'

# %%
url_req=requests.get(url)

# %%
url_req.status_code
# Out:
# 200

# %%
print(url_req.text)
# Out:
# <!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head><meta charset="utf-8"><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66
# ...

# %%
soup=BeautifulSoup(url_req.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script>
#    var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";
#   </script>
#   <style>
# ...

# %%
soup.title
# Out:
# <title itemprop="name">Live Cricket Score, Schedule, Latest News, Stats &amp; Videos | Cricbuzz.com</title>

# %%
soup.title.string
# Out:
# 'Live Cricket Score, Schedule, Latest News, Stats & Videos | Cricbuzz.com'

# %%
soup.div
# Out:
# <div class="container"><div class="ad-unit text-center center-block" id="leaderboard" style="min-height:90px;margin-bottom:10px;"></div><div class="ad-unit" id="countdown" style="margin:-10px 15px 0px;float:right;position:absolute;"></div><div class="toi-branding toi-referral"></div><nav class="cb-nav cb-col cb-col-100" id="cb-main-menu" ng-controller="CBPlusAuth"><a class="cb-hm-text" href="/" target="_self"><img alt="Cricbuzz Logo" height="40" id="cb-logo-main-menu" itemprop="image" src="/images/cb_logo.svg" style="bottom: 4px; position: relative; vertical-align:middle;" title="Cricbuzz Logo" width="101"/></a><a class="cb-hm-mnu-itm" href="/cricket-match/live-scores" target="_self" title="Live Cricket Score">Live Scores</a><a class="cb-hm-mnu-itm" href="/cricket-schedule/upcoming-series/international" target="_self" title="Cricket Schedule">Schedule</a><a class="cb-hm-mnu-itm" href="/cricket-scorecard-archives" target="_self" title="Cricket Scorecard Archives">Archives</a><div clas
# ...

# %%
soup.a
# Out:
# <a href="https://plus.google.com/104502282508811467249" rel="publisher"></a>

# %%
soup.find_all("a")
# Out:
# [<a href="https://plus.google.com/104502282508811467249" rel="publisher"></a>,
#  <a class="cb-skin-ads-link cb-skin-ads-link-fixed ad-skin" href="Javascript:void(0)" id="ad-skin" target="_blank"></a>,
#  <a class="cb-skin-ads-close cb-font-12 ad-skin-close" href="Javascript:void(0)" style="position:fixed; z-index:1001; color:#FFF; background:#000; padding:2px 5px; right:2px;">✖</a>,
#  <a class="cb-hm-text" href="/" target="_self"><img alt="Cricbuzz Logo" height="40" id="cb-logo-main-menu" itemprop="image" src="/images/cb_logo.svg" style="bottom: 4px; position: relative; vertical-align:middle;" title="Cricbuzz Logo" width="101"/></a>,
#  <a class="cb-hm-mnu-itm" href="/cricket-match/live-scores" target="_self" title="Live Cricket Score">Live Scores</a>,
#  <a class="cb-hm-mnu-itm" href="/cricket-schedule/upcoming-series/international" target="_self" title="Cricket Schedule">Schedule</a>,
# ...

# %%
all_links=soup.find_all("a")
for r in all_links:
    print(r.get('href'))
# Out:
# https://plus.google.com/104502282508811467249
# Javascript:void(0)
# Javascript:void(0)
# /
# /cricket-match/live-scores
# /cricket-schedule/upcoming-series/international
# /cricket-scorecard-archives
# /cricket-news
# /cricket-news
# /cricket-news/editorial/cb-plus
# /cricket-news/latest-news
# /cricket-news/info/
# /cricket-news/editorial/spotlight
# /cricket-news/editorial/editorial-list
# /cricket-news/editorial/specials
# /cricket-news/editorial/stats-analysis
# /cricket-news/editorial/interviews
# /cricket-news/editorial/live-blogs
# /cricket-news/experts/harsha-bhogle/170
# /cricket-schedule/series
# /cricket-series/4905/india-tour-of-bangladesh-2022
# /cricket-series/4492/england-tour-of-pakistan-2022
# /cricket-series/4245/west-indies-tour-of-australia-2022
# /cricket-series/4254/south-africa-tour-of-australia-2022-23
# /cricket-series/5080/india-a-tour-of-bangladesh-2022
# /cricket-series/4455/lanka-premier-league-2022
# /cricket-series/4534/ranji-trophy-2022-23
# ...

# %%
all_table=soup.find_all('table')
print(all_table)
# Out:
# []

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html itemscope="" itemtype="http://schema.org/WebPage" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <script>\n   var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);\tif(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";\n  </script>\n  <style>\n   body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}\tbody, .cb-comm-pg, .cb-hm-mid {min-height:1000px}\t.container{width:980px;margin:0 auto;}\t.page{max-width: 980px;margin: 0 auto;position: relative;}\t.cb-col-8 {width:8%;}\t.cb-col-10 {width:10%;}\t.cb-col-14 {width:14%;}\t.cb-col-16 {width:16%;}\t.cb-col-20 {width:20%;}\t.cb-col-25 {width:25%;}\t.cb-col-27 {width:27%;}\t.cb-col-30 {width:30%;}\t.cb-col-33 {width:33%;}\t.cb-col-40 {width:40%;}\t.cb-col-46 {width:46%;}\t.cb-col-47 {width:47%;}\t.cb-col-50 {width:50%;}\t.cb-
# ...

# %%
model=soup.findAll('div',{'class':'crd-cntxt'})

# %%
model
# Out:
# [<div class="crd-cntxt"><span>BAN VS IND, 1ST TEST</span></div>,
#  <div class="crd-cntxt"><span>DIALOGUE ROOM </span></div>,
#  <div class="crd-cntxt"><span>IPL TRIMMED AUCTION LIST</span></div>,
#  <div class="crd-cntxt"><span>ENGLAND TOUR OF PAKISTAN, 2022</span></div>,
#  <div class="crd-cntxt"><span>AUSTRALIA WOMEN TOUR OF INDIA, 2022</span></div>,
#  <div class="crd-cntxt"><span>BOOK EXTRACT - UNVEILING JAZBAA</span></div>,
#  <div class="crd-cntxt"><span>SOUTH AFRICA'S TOUR OF AUSTRALIA, 2022-23</span></div>,
#  <div class="crd-cntxt">ACCIDENT</div>,
#  <div class="crd-cntxt"><span>MASTERCARD ADVERTORIAL</span></div>,
#  <div class="crd-cntxt"><span>RANJI TROPHY</span></div>,
#  <div class="crd-cntxt">OUTSIDE THE CIRCLE</div>,
#  <div class="crd-cntxt">BBL 2022-23</div>,
#  <div class="crd-cntxt">INDIA VS BANGLADESH</div>,
#  <div class="crd-cntxt">WEST INDIES TOUR OF AUSTRALIA, 2022</div>,
#  <div class="crd-cntxt">INDIA TOUR OF BANGLADESH, 2022</div>,
# ...

# %%
news_name=[]
for i in model:
    p=i.text
    news_name.append(p)

# %%
news_name
# Out:
# ['BAN VS IND, 1ST TEST',
#  'DIALOGUE ROOM ',
#  'IPL TRIMMED AUCTION LIST',
#  'ENGLAND TOUR OF PAKISTAN, 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA, 2022',
#  'BOOK EXTRACT - UNVEILING JAZBAA',
#  "SOUTH AFRICA'S TOUR OF AUSTRALIA, 2022-23",
#  'ACCIDENT',
#  'MASTERCARD ADVERTORIAL',
#  'RANJI TROPHY',
#  'OUTSIDE THE CIRCLE',
#  'BBL 2022-23',
#  'INDIA VS BANGLADESH',
#  'WEST INDIES TOUR OF AUSTRALIA, 2022',
#  'INDIA TOUR OF BANGLADESH, 2022',
#  'THE 2018 AFTERMATH',
#  'THINK TANK']

# %%
len(news_name)
# Out:
# 17

# %%
type(news_name)
# Out:
# list

# %%
cricket_wickets = soup.findAll('div',{'clss':'cb-font-24 inline-block cb-ttl-wkt-nm'})

# %%
cricket_wickets
# Out:
# []

# %%
cricket_shedule = soup.findAll('div',{'class':'cb-bg-white cb-schdl cb-col cb-col-100'})

# %%
cricket_shedule
# Out:
# []

# %%
latest_news=soup.findAll('div',{'id':'page-wrapper'})

# %%
latest_news
# Out:
# [<div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/56969/ind-vs-ban-1st-test-india-tour-of-bangladesh-2022" target="_self" title="India v Bangladesh, 1st Test - Stumps">IND vs BAN - Stumps</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/58936/indw-vs-ausw-3rd-t20i-australia-women-tour-of-india-2022" target="_self" tit
# ...

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = {'news_name':news_name}

# %%
df
# Out:
# {'news_name': ['BAN VS IND, 1ST TEST',
#   'DIALOGUE ROOM ',
#   'IPL TRIMMED AUCTION LIST',
#   'ENGLAND TOUR OF PAKISTAN, 2022',
#   'AUSTRALIA WOMEN TOUR OF INDIA, 2022',
#   'BOOK EXTRACT - UNVEILING JAZBAA',
#   "SOUTH AFRICA'S TOUR OF AUSTRALIA, 2022-23",
#   'ACCIDENT',
#   'MASTERCARD ADVERTORIAL',
#   'RANJI TROPHY',
#   'OUTSIDE THE CIRCLE',
#   'BBL 2022-23',
#   'INDIA VS BANGLADESH',
#   'WEST INDIES TOUR OF AUSTRALIA, 2022',
#   'INDIA TOUR OF BANGLADESH, 2022',
#   'THE 2018 AFTERMATH',
#   'THINK TANK']}

# %%
data = pd.DataFrame(df)
data
# Out:
#                                     news_name
# 0                        BAN VS IND, 1ST TEST
# 1                              DIALOGUE ROOM
# 2                    IPL TRIMMED AUCTION LIST
# 3              ENGLAND TOUR OF PAKISTAN, 2022
# 4         AUSTRALIA WOMEN TOUR OF INDIA, 2022
# 5             BOOK EXTRACT - UNVEILING JAZBAA
# 6   SOUTH AFRICA'S TOUR OF AUSTRALIA, 2022-23
# 7                                    ACCIDENT
# 8                      MASTERCARD ADVERTORIAL
# 9                                RANJI TROPHY
# 10                         OUTSIDE THE CIRCLE
# 11                                BBL 2022-23
# 12                        INDIA VS BANGLADESH
# 13        WEST INDIES TOUR OF AUSTRALIA, 2022
# 14             INDIA TOUR OF BANGLADESH, 2022
# 15                         THE 2018 AFTERMATH
# 16                                 THINK TANK
